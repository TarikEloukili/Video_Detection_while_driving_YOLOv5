# %%
import os
HOME= os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install kaggle --upgrade --quiet

# %%
from getpass import getpass
os.environ["KAGGLE_USERNAME"] = getpass("Enter Kaggle Username: ")
os.environ["KAGGLE_KEY"] = getpass("Enter Kaggle Key: ")
# Out:
# Enter Kaggle Username: ··········
# Enter Kaggle Key: ··········

# %%
# !kaggle datasets download -d krimimohamed/cars-video
# Out:
# Dataset URL: https://www.kaggle.com/datasets/krimimohamed/cars-video
# License(s): CC0-1.0
# ...
#   0% 0.00/6.21M [00:00<?, ?B/s]
# 100% 6.21M/6.21M [00:00<00:00, 624MB/s]

# %%
# %cd {HOME}
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# %pip install -r requirements.txt

import torch
import utils

display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-419-gcd44191c Python-3.11.12 torch-2.6.0+cu124 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.4/107.7 GB disk)

# %%
# !unzip {HOME}/cars-video.zip
# Out:
# Archive:  /content/cars-video.zip
#   inflating: video.mp4

# %%
# %cd {HOME}/yolov5
# !python detect.py  --img 640 --conf 0.25 --source video.mp4 --name coco
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# video 1/1 (399/5396) /content/yolov5/video.mp4: 384x640 4 cars, 1 truck, 331.8ms
# video 1/1 (400/5396) /content/yolov5/video.mp4: 384x640 4 cars, 1 truck, 333.3ms
# video 1/1 (401/5396) /content/yolov5/video.mp4: 384x640 4 cars, 1 truck, 326.0ms
# video 1/1 (402/5396) /content/yolov5/video.mp4: 384x640 4 cars, 1 truck, 1 bird, 346.7ms
# video 1/1 (403/5396) /content/yolov5/video.mp4: 384x640 4 cars, 1 truck, 361.0ms
# video 1/1 (404/5396) /content/yolov5/video.mp4: 384x640 4 cars, 1 truck, 344.7ms
# video 1/1 (405/5396) /content/yolov5/video.mp4: 384x640 4 cars, 2 trucks, 318.7ms
# video 1/1 (406/5396) /content/yolov5/video.mp4: 384x640 5 cars, 1 truck, 319.4ms
# video 1/1 (407/5396) /content/yolov5/video.mp4: 384x640 4 cars, 1 truck, 379.1ms
# video 1/1 (408/5396) /content/yolov5/video.mp4: 384x640 5 cars, 1 truck, 477.3ms
# ...
